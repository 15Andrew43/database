# %%
import pandas as pd

# %%
df = pd.read_csv('./rdt_16201271154643.csv', sep='\t')
df.head()
# Out:
#      Фамилия      Имя     Отчество Дата рождения Серия и номер паспорта
# 0  Криштофич  Зинаида    Захаровна    21.12.1973            4137 761086
# 1    Куликов  Николай   Витальевич    16.09.1990            4893 753917
# 2   Анисимов     Марк        Ильич    11.08.1994            4822 224954
# 3   Иванкова     Нина     Марковна    10.06.1974            4238 721929
# 4    Валеева    Алена  Серафимовна    12.02.1967            4594 816487

# %%
for index, row in df.iterrows():
    last_name, name, patron, date, passport = row
    date = date.split('.')
    a = "'"
    print(f"insert into project.passengers values ({index + 1000}, {a+name+a}, {a+last_name+a}, {a+patron+a}, {a+'-'.join(date[::-1])+a}, {a+str(passport)+a});")
# Out:
# insert into project.passengers values (1000, 'Зинаида', 'Криштофич', 'Захаровна', '1973-12-21', '4137 761086');
# insert into project.passengers values (1001, 'Николай', 'Куликов', 'Витальевич', '1990-09-16', '4893 753917');
# insert into project.passengers values (1002, 'Марк', 'Анисимов', 'Ильич', '1994-08-11', '4822 224954');
# insert into project.passengers values (1003, 'Нина', 'Иванкова', 'Марковна', '1974-06-10', '4238 721929');
# insert into project.passengers values (1004, 'Алена', 'Валеева', 'Серафимовна', '1967-02-12', '4594 816487');
# insert into project.passengers values (1005, 'Василий', 'Соломахин', 'Кузьмич', '1982-11-03', '4625 996691');
# insert into project.passengers values (1006, 'Кирилл', 'Смольников', 'Антонович', '1988-05-03', '4517 988974');
# insert into project.passengers values (1007, 'Наталия', 'Абумайлова', 'Валериановна', '1977-08-18', '4159 174662');
# ...

# %%
df.head()
# Out:
#      Фамилия      Имя     Отчество Дата рождения Серия и номер паспорта
# 0  Криштофич  Зинаида    Захаровна    21.12.1973            4137 761086
# 1    Куликов  Николай   Витальевич    16.09.1990            4893 753917
# 2   Анисимов     Марк        Ильич    11.08.1994            4822 224954
# 3   Иванкова     Нина     Марковна    10.06.1974            4238 721929
# 4    Валеева    Алена  Серафимовна    12.02.1967            4594 816487
